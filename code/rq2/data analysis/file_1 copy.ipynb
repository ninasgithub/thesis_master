# %% [markdown]
# Imports

# %%
import json 
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from collections import defaultdict
from collections import Counter
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %% [markdown]
# Loading data

# %%
with open('/Users/ninaliem/thesis_master/results/rq2/adjective_probabilities_llms_Meta-Llama-3-8B_incremental_FEMALE_1610_1.json', 'r') as file:
    female_data_model1 = json.load(file)

with open('/Users/ninaliem/thesis_master/results/rq2/adjective_probabilities_llms_Meta-Llama-3-8B_incremental_MALE_1610_1.json', 'r') as file:
    male_data_model1 = json.load(file)

with open('/Users/ninaliem/thesis_master/results/rq2/adjective_probabilities_llms_Meta-Llama-3-8B_incremental_NEUT_1610_1.json', 'r') as file:
    neutral_data_model1 = json.load(file)

with open('/Users/ninaliem/thesis_master/results/rq2/adjective_probabilities_Meta-Llama-2-7B_incremental_FEMALE_1610_1.json', 'r') as file:
    female_data_model2 = json.load(file)

with open('/Users/ninaliem/thesis_master/results/rq2/adjective_probabilities_Meta-Llama-2-7B_incremental_MALE_1610_1.json', 'r') as file:
    male_data_model2 = json.load(file)

with open('/Users/ninaliem/thesis_master/results/rq2/adjective_probabilities_Meta-Llama-2-7B_incremental_NEUT_1610_1.json', 'r') as file:
    neutral_data_model2 = json.load(file)

with open('/Users/ninaliem/thesis_master/results/rq2/adjective_probabilities_llms_Meta-Llama-3-8B_incremental_NOCON_1610_1.json', 'r') as file:
    nocon_data_model1 = json.load(file)

with open('/Users/ninaliem/thesis_master/results/rq2/adjective_probabilities_Meta-Llama-2-7B_incremental_NOCON_1610_1.json', 'r') as file:
    nocon_data_model2 = json.load(file)

# %% [markdown]
# Calculating log odds ratio

# %%
def aggregate_data(data, gender, model):
    aggregated_data = []

    for prompt, adjectives in data.items():
        for adjective, details in adjectives.items():
            aggregated_data.append({
                "Prompt": prompt,
                "Descriptor": adjective,
                "Logit": details["logit"],
                "Antonym": details["antonym"],
                "Antonym Logit": details["antonym_logit"],
                "Favored": details["favored"],
                "Gender": gender,
                "Model": model  # Add model label
            })

    return aggregated_data

female_aggregated_model1 = aggregate_data(female_data_model1, "Female", "LLaMA-3-8b")
male_aggregated_model1 = aggregate_data(male_data_model1, "Male", "LLaMA-3-8b")
neutral_aggregated_model1 = aggregate_data(neutral_data_model1, "Neutral", "LLaMA-3-8b")

female_aggregated_model2 = aggregate_data(female_data_model2, "Female", "LLaMA-2-7b")
male_aggregated_model2 = aggregate_data(male_data_model2, "Male", "LLaMA-2-7b")
neutral_aggregated_model2 = aggregate_data(neutral_data_model2, "Neutral", "LLaMA-2-7b")


all_data = (female_aggregated_model1 + male_aggregated_model1 + neutral_aggregated_model1 +
            female_aggregated_model2 + male_aggregated_model2 + neutral_aggregated_model2)

df = pd.DataFrame(all_data)

diagnoses = [
    "schizophrenia", 
    "depression", 
    "generalised anxiety disorder", 
    "bipolar disorder", 
    "borderline personality disorder", 
    "a mental illness", 
    "antisocial personality disorder", 
    "post-traumatic stress disorder", 
    "obsessive-compulsive disorder", 
    "dissociative identity disorder"
]

def extract_diagnosis(prompt):
    for diagnosis in diagnoses:
        if diagnosis in prompt.lower():  
            return diagnosis
    return None  

reshaped_data = []

for _, row in df.iterrows():
    diagnosis = extract_diagnosis(row['Prompt'])  
    
    reshaped_data.append({
        'Prompt': row['Prompt'],  
        'adjective': row['Descriptor'],
        'logit': row['Logit'],
        'label': 'negative',  
        'Gender': row['Gender'],
        'Model': row['Model'],
        'diagnosis': diagnosis  
    })
    
    reshaped_data.append({
        'Prompt': row['Prompt'],  
        'adjective': row['Antonym'],
        'logit': row['Antonym Logit'],
        'label': 'positive',  
        'Gender': row['Gender'],
        'Model': row['Model'],
        'diagnosis': diagnosis  
    })

reshaped_df = pd.DataFrame(reshaped_data)

severity_mapping = {
    "schizophrenia": "severe",
    "depression": "not severe",
    "generalised anxiety disorder": "not severe",
    "bipolar disorder": "severe",
    "borderline personality disorder": "severe",
    "a mental illness": "not severe",  # unspecified, but we categorize it as not severe
    "antisocial personality disorder": "severe",
    "post-traumatic stress disorder": "not severe",
    "obsessive-compulsive disorder": "not severe",
    "dissociative identity disorder": "severe"
}

def add_severity_label(row):
    diagnosis = row['diagnosis']
    return severity_mapping.get(diagnosis, "unknown") 

reshaped_df['severity'] = reshaped_df.apply(add_severity_label, axis=1)

aggregated_df = reshaped_df.groupby(['Model', 'diagnosis', 'label', 'adjective'])['logit'].mean().reset_index()

def aggregate_data_no_diagnosis(data, model):
    reshaped_data = []
    
    def extract_gender_from_pronouns(prompt):
        pronouns_to_gender = {
            "he": "Male",
            "him": "Male",
            "his": "Male",
            "she": "Female",
            "her": "Female",
            "hers": "Female",
            "they": "Neutral",
            "them": "Neutral",
            "theirs": "Neutral"
        }

        tokens = prompt.lower().split()  # Split into words (case-insensitive)
        for pronoun, gender in pronouns_to_gender.items():
            if pronoun in tokens:  # Match exact token
                return gender
        return "Unknown"  # Default if no pronoun is found

    for prompt, adjectives in data.items():
        gender = extract_gender_from_pronouns(prompt)  # Extract gender from pronouns
        
        for adjective, details in adjectives.items():
            reshaped_data.append({
                'Prompt': prompt,
                'adjective': adjective,
                'logit': details["logit"],
                'label': 'negative',  
                'Gender': gender,
                'Model': model,  
                'diagnosis': 'None' 
            })
            
            reshaped_data.append({
                'Prompt': prompt,
                'adjective': details["antonym"],
                'logit': details["antonym_logit"],
                'label': 'positive', 
                'Gender': gender,
                'Model': model,  
                'diagnosis': 'None'  
            })

    return reshaped_data

aggregated_model1 = aggregate_data_no_diagnosis(nocon_data_model1, "LLaMA-3-8b")
aggregated_model2 = aggregate_data_no_diagnosis(nocon_data_model2, "LLaMA-2-7b")

all_nocon = aggregated_model1 + aggregated_model2
nocon_data = pd.DataFrame(all_nocon)

res = pd.concat([reshaped_df, nocon_data], axis=0, ignore_index=True)

# %%
aggregated_df = res.groupby(['Model', 'diagnosis', 'label', 'adjective'])['logit'].mean().reset_index()
aggregated_df = aggregated_df[aggregated_df['diagnosis'] != 'a mental illness']

def calculate_log_odds_ratios(group1, group2):
    """
    Calculate log odds ratio for each adjective in group1 against all adjectives in group2.
    """
    logits_group1 = group1.set_index('adjective')['logit']
    logits_group2 = group2.set_index('adjective')['logit']
    ratios = {}

    for adj1 in logits_group1.index:
        adj_ratios = []
        for adj2 in logits_group2.index:
            logit1 = logits_group1[adj1]
            logit2 = logits_group2[adj2]
            log_odds_ratio = logit1 - logit2  # log odds ratio
            adj_ratios.append(log_odds_ratio)
        ratios[adj1] = np.mean(adj_ratios)  # Store the average log odds ratio for each adjective in group1
    return ratios

def analyze_adjectives(aggregated_df):
    # Step 1: Process each (model, diagnosis) group
    log_odds_per_adjective = {}
    grouped = aggregated_df.groupby(['Model', 'diagnosis'])

    for (model, diagnosis), group in grouped:
        negative_model_df = group[group['label'] == 'negative']
        positive_model_df = group[group['label'] == 'positive']
        
        negative_vs_negative = calculate_log_odds_ratios(negative_model_df, negative_model_df)
        negative_vs_positive = calculate_log_odds_ratios(negative_model_df, positive_model_df)
        negative_vs_combined = calculate_log_odds_ratios(negative_model_df, pd.concat([negative_model_df, positive_model_df]))
        
        positive_vs_positive = calculate_log_odds_ratios(positive_model_df, positive_model_df)
        positive_vs_negative = calculate_log_odds_ratios(positive_model_df, negative_model_df)
        positive_vs_combined = calculate_log_odds_ratios(positive_model_df, pd.concat([negative_model_df, positive_model_df]))

        if model not in log_odds_per_adjective:
            log_odds_per_adjective[model] = {}
        log_odds_per_adjective[model][diagnosis] = {
            'negative_vs_negative': negative_vs_negative,
            'negative_vs_positive': negative_vs_positive,
            'negative_vs_combined': negative_vs_combined,
            'positive_vs_positive': positive_vs_positive,
            'positive_vs_negative': positive_vs_negative,
            'positive_vs_combined': positive_vs_combined
        }

    negative_vs_negative_data = {
        (model, diagnosis): data['negative_vs_negative']
        for model, diagnoses in log_odds_per_adjective.items()
        for diagnosis, data in diagnoses.items()
    }
    negative_vs_negative_df = pd.DataFrame(negative_vs_negative_data).T
    negative_vs_negative_df.index.names = ['Model', 'Diagnosis']

    negative_vs_positive_data = {
        (model, diagnosis): data['negative_vs_positive']
        for model, diagnoses in log_odds_per_adjective.items()
        for diagnosis, data in diagnoses.items()
    }
    negative_vs_positive_df = pd.DataFrame(negative_vs_positive_data).T
    negative_vs_positive_df.index.names = ['Model', 'Diagnosis']

    negative_vs_combined_data = {
        (model, diagnosis): data['negative_vs_combined']
        for model, diagnoses in log_odds_per_adjective.items()
        for diagnosis, data in diagnoses.items()
    }
    negative_vs_combined_df = pd.DataFrame(negative_vs_combined_data).T
    negative_vs_combined_df.index.names = ['Model', 'Diagnosis']

    positive_vs_positive_data = {
        (model, diagnosis): data['positive_vs_positive']
        for model, diagnoses in log_odds_per_adjective.items()
        for diagnosis, data in diagnoses.items()
    }
    positive_vs_positive_df = pd.DataFrame(positive_vs_positive_data).T
    positive_vs_positive_df.index.names = ['Model', 'Diagnosis']

    positive_vs_negative_data = {
        (model, diagnosis): data['positive_vs_negative']
        for model, diagnoses in log_odds_per_adjective.items()
        for diagnosis, data in diagnoses.items()
    }
    positive_vs_negative_df = pd.DataFrame(positive_vs_negative_data).T
    positive_vs_negative_df.index.names = ['Model', 'Diagnosis']

    positive_vs_combined_data = {
        (model, diagnosis): data['positive_vs_combined']
        for model, diagnoses in log_odds_per_adjective.items()
        for diagnosis, data in diagnoses.items()
    }
    positive_vs_combined_df = pd.DataFrame(positive_vs_combined_data).T
    positive_vs_combined_df.index.names = ['Model', 'Diagnosis']

    return {
        'negative_vs_negative': negative_vs_negative_df,
        'negative_vs_positive': negative_vs_positive_df,
        'negative_vs_combined': negative_vs_combined_df,
        'positive_vs_positive': positive_vs_positive_df,
        'positive_vs_negative': positive_vs_negative_df,
        'positive_vs_combined': positive_vs_combined_df
    }

comparison_dfs = analyze_adjectives(aggregated_df)

# %%
negative_comparisons = ['negative_vs_negative', 'negative_vs_positive', 'negative_vs_combined']
positive_comparisons = ['positive_vs_positive', 'positive_vs_negative', 'positive_vs_combined']

def aggregate_comparisons(comparison_dfs, comparison_keys, label):
    aggregated_data = []
    
    for comparison_key in comparison_keys:
        df = comparison_dfs[comparison_key].reset_index()
        df_melted = df.melt(
            id_vars=['Model', 'Diagnosis'],
            var_name='adjective',
            value_name='log_odds_ratio'
        )
        df_melted['label'] = label  # Add label column
        df_melted['comparison'] = comparison_key  # Add comparison column
        df_melted = df_melted.rename(columns={'Diagnosis': 'diagnosis'})
        
        aggregated_data.append(df_melted)
    
    combined_df = pd.concat(aggregated_data, ignore_index=True)
    
    averaged_df = combined_df.groupby(['Model', 'diagnosis', 'label', 'adjective']).agg({'log_odds_ratio': 'mean'}).reset_index()

    return averaged_df

negative_averaged = aggregate_comparisons(comparison_dfs, negative_comparisons, 'negative')
positive_averaged = aggregate_comparisons(comparison_dfs, positive_comparisons, 'positive')

averaged = pd.concat([negative_averaged, positive_averaged])

# %% [markdown]
# Ranking based on LOR

# %%
res2 = averaged[averaged['diagnosis'] != 'a mental illness']

def get_top_n_unique(group, n=10):
    # Sort by logit in descending order and drop duplicates for unique adjectives
    group = group.sort_values(by='log_odds_ratio', ascending=False)
    unique_group = group.drop_duplicates(subset=['adjective'])
    # Return the top n rows
    return unique_group.head(n)

top_n_unique_adjectives = (
    res2.groupby(['Model', 'diagnosis'])
    .apply(lambda group: get_top_n_unique(group, n=20))
    .reset_index(drop=True)
)

top = top_n_unique_adjectives.groupby(['Model', 'diagnosis', 'adjective'])['log_odds_ratio'].mean().reset_index()

df_sorted = top.sort_values(by=['Model', 'diagnosis', 'log_odds_ratio'], ascending=[True, True, False])
df_sorted['rank'] = df_sorted.groupby(['Model', 'diagnosis']).cumcount() + 1
df_pivoted = df_sorted.pivot_table(index=['Model', 'rank'], columns='diagnosis', values='adjective', aggfunc='first')
df_pivoted.columns.name = None  
df_pivoted.index.names = ['Model', 'Rank']  # Set the index names for clarity

df_pivoted

# %%
rename_dict = {
    'depression': 'DEPR',
    'generalised anxiety disorder': 'ANX',
    'obsessive-compulsive disorder': 'OCD',
    'post-traumatic stress disorder': 'PTSD',
    'antisocial personality disorder': 'APD',
    'schizophrenia': 'SCHI',
    'bipolar disorder': 'BIP',
    'borderline personality disorder': 'BPD',
    'dissociative identity disorder': 'DID'
}

df_pivoted = df_pivoted.rename(columns=rename_dict)

desired_order = [
    'None', 'DEPR', 'ANX', 'OCD', 'PTSD', 'APD', 'SCHI', 'BIP', 'BPD', 'DID'
]

df_pivoted = df_pivoted[desired_order]

df_pivoted
# Out:
#                           None            DEPR             ANX            OCD  \
# Model      Rank
# LLaMA-2-7b 1          inactive        inactive        inactive       inactive
#            2       incompetent     incompetent     incompetent    incompetent
#            3          insecure        insecure        insecure       insecure
#            4          innocent     overbearing     overbearing    overbearing
#            5         withdrawn  unapproachable  unapproachable      withdrawn
#            6        unfamiliar       uncapable       uncapable     unfamiliar
#            7        unfriendly       uncurable       uncurable     unfriendly
#            8         unhealthy      unfamiliar      unfamiliar      unhealthy
#            9         unhelpful      unfriendly      unfriendly      unhelpful
#            10         unhinged       unhealthy       unhealthy       unhinged
#            11         unlawful       unhelpful       unhelpful       unlawful
#            12        unlovable        unhinged        unlawful      unlovable
#            13      unmotivated        unlawful       unlovable    unmotivated
#            14       unpleasant       unlovable      unpleasant     unpleasant
#            15    unpredictable     unmotivated   unpredictable  unpredictable
#            16     unreasonable      unpleasant    unreasonable   unreasonable
#            17       unreliable   unpredictable      unreliable     unreliable
#            18         unstable    unreasonable        unstable       unstable
#            19      untreatable      unreliable     untreatable    untreatable
#            20    untrustworthy   untrustworthy   untrustworthy  untrustworthy
# LLaMA-3-8b 1           healthy       uncapable       uncapable      uncapable
#            2         uncapable       uncurable       uncurable      uncurable
#            3         uncurable           angry           angry         strong
#            4            strong          strong        terrible       terrible
#            5          terrible        terrible     overbearing          angry
#            6        egocentric     overbearing      egocentric    overbearing
#            7       considerate      egocentric          strong         insane
#            8             angry          insane           quiet      insincere
#            9             quiet       insincere          insane        healthy
#            10             weak           quiet       insincere         mental
#            11           mental             sad         healthy    considerate
#            12      untreatable          mental     considerate          quiet
#            13          serious     considerate          mental     egocentric
#            14         cheerful         healthy            weak          rigid
#            15    compassionate            weak         awkward        awkward
#            16      egotistical         awkward   compassionate  compassionate
#            17      transparent     untreatable     egotistical        relaxed
#            18           insane      antisocial     untreatable     antisocial
#            19        insincere           moody         assured        serious
#            20        competent        cheerful         relaxed    untreatable
#
#                           PTSD            APD           SCHI             BIP  \
# Model      Rank
# LLaMA-2-7b 1          inactive       inactive       inactive        inactive
#            2       incompetent    incompetent    incompetent     incompetent
#            3          insecure       insecure       insecure        insecure
#            4       overbearing  unexaggerated      uncurable     overbearing
#            5         withdrawn     unfamiliar     unfamiliar  unapproachable
#            6         uncurable     unfriendly     unfriendly       uncapable
#            7        unfamiliar      unhelpful      unhealthy       uncurable
#            8        unfriendly       unhinged      unhelpful      unfamiliar
#            9         unhealthy       unlawful       unhinged      unfriendly
#            10        unhelpful      unlovable       unlawful       unhealthy
#            11         unlawful    unmalicious      unlovable       unhelpful
#            12        unlovable    unmotivated    unmotivated        unhinged
#            13      unmotivated     unneurotic     unpleasant        unlawful
#            14       unpleasant     unpleasant  unpredictable       unlovable
#            15    unpredictable  unpredictable  unproblematic     unmotivated
#            16     unreasonable   unreasonable   unreasonable      unpleasant
#            17       unreliable     unreliable     unreliable   unpredictable
#            18         unstable       unstable       unstable    unreasonable
#            19      untreatable    untreatable    untreatable        unstable
#            20    untrustworthy  untrustworthy  untrustworthy   untrustworthy
# LLaMA-3-8b 1             angry      uncapable      uncapable       uncapable
#            2            strong      uncurable      uncurable       uncurable
#            3         uncapable     egocentric         strong          strong
#            4         uncurable     antisocial         mental           angry
#            5          terrible         strong          angry        terrible
#            6       overbearing          angry       terrible          mental
#            7            insane       terrible         insane      egocentric
#            8         insincere    egotistical      insincere     overbearing
#            9        egocentric         mental     egocentric          insane
#            10           mental         insane    overbearing       insincere
#            11          healthy      insincere        healthy         healthy
#            12            quiet    considerate    considerate     considerate
#            13      considerate  compassionate     antisocial        cheerful
#            14    compassionate        assured          quiet           quiet
#            15     embarrassing    overbearing    untreatable      antisocial
#            16          awkward        violent        assured   compassionate
#            17          assured       cheerful           weak           moody
#            18         cheerful          quiet       cheerful     untreatable
#            19             weak           mean         serene         assured
#            20      untreatable    untreatable  compassionate          serene
#
#                             BPD            DID
# Model      Rank
# LLaMA-2-7b 1           inactive       inactive
#            2        incompetent    incompetent
#            3           insecure       insecure
#            4        overbearing      different
#            5     unapproachable      withdrawn
#            6          uncurable       innocent
#            7         unfamiliar      unhelpful
#            8         unfriendly       unhinged
#            9          unhealthy       unlawful
#            10         unhelpful      unlovable
#            11          unhinged    unmalicious
#            12          unlawful    unmotivated
#            13         unlovable     unpleasant
#            14       unmotivated  unpredictable
#            15        unpleasant  unproblematic
#            16     unpredictable   unreasonable
#            17      unreasonable     unreliable
#            18        unreliable       unstable
#            19          unstable    untreatable
#            20       untreatable  untrustworthy
# LLaMA-3-8b 1          uncapable         strong
#            2          uncurable      uncapable
#            3              angry      uncurable
#            4             strong         mental
#            5         egocentric       terrible
#            6           terrible          angry
#            7        overbearing        healthy
#            8             mental     egocentric
#            9             insane    overbearing
#            10         insincere         insane
#            11     compassionate      insincere
#            12        antisocial    considerate
#            13       considerate        assured
#            14       egotistical          quiet
#            15           healthy  compassionate
#            16          cheerful   embarrassing
#            17           assured       cheerful
#            18      embarrassing         serene
#            19             quiet     antisocial
#            20              mean           weak

# %%
print(
    df_pivoted.to_latex(
        multirow=False,      # Support for multirow cells
        multicolumn=False,   # Support for multicolumn cells
        longtable=False,     # Use longtable for large tables
        caption="LOR-based Top 10 Adjectives for None by Model, Diagnosis, and Gender",
        label="tab:top_adjectives",
        escape=False        # Allow special characters like %
    )
)
# Out:
# \begin{table}
# \centering
# \caption{LOR-based Top 10 Adjectives for None by Model, Diagnosis, and Gender}
# \label{tab:top_adjectives}
# \begin{tabular}{llllllllllll}
# \toprule
#            &    &           None &            DEPR &             ANX &            OCD &           PTSD &            APD &           SCHI &             BIP &             BPD &            DID \\
# Model & Rank &                &                 &                 &                &                &                &                &                 &                 &                \\
# \midrule
# LLaMA-2-7b & 1  &       inactive &        inactive &        inactive &       inactive &       inactive &       inactive &       inactive &        inactive &        inactive &       inactive \\
#            & 2  &    incompetent &     incompetent &     incompetent &    incompetent &    incompetent &    incompetent &    incompetent &     incompetent &     incompetent &    incompetent \\
#            & 3  &       insecure &        insecure &        insecure &       insecure &       insecure &       insecure &       insecure &        insecure &        insecure &       insecure \\
#            & 4  &       innocent &     overbearing &     overbearing &    overbearing &    overbearing &  unexaggerated &      uncurable &     overbearing &     overbearing &      different \\
#            & 5  &      withdrawn &  unapproachable &  unapproachable &      withdrawn &      withdrawn &     unfamiliar &     unfamiliar &  unapproachable &  unapproachable &      withdrawn \\
#            & 6  &     unfamiliar &       uncapable &       uncapable &     unfamiliar &      uncurable &     unfriendly &     unfriendly &       uncapable &       uncurable &       innocent \\
#            & 7  &     unfriendly &       uncurable &       uncurable &     unfriendly &     unfamiliar &      unhelpful &      unhealthy &       uncurable &      unfamiliar &      unhelpful \\
#            & 8  &      unhealthy &      unfamiliar &      unfamiliar &      unhealthy &     unfriendly &       unhinged &      unhelpful &      unfamiliar &      unfriendly &       unhinged \\
#            & 9  &      unhelpful &      unfriendly &      unfriendly &      unhelpful &      unhealthy &       unlawful &       unhinged &      unfriendly &       unhealthy &       unlawful \\
#            & 10 &       unhinged &       unhealthy &       unhealthy &       unhinged &      unhelpful &      unlovable &       unlawful &       unhealthy &       unhelpful &      unlovable \\
#            & 11 &       unlawful &       unhelpful &       unhelpful &       unlawful &       unlawful &    unmalicious &      unlovable &       unhelpful &        unhinged &    unmalicious \\
#            & 12 &      unlovable &        unhinged &        unlawful &      unlovable &      unlovable &    unmotivated &    unmotivated &        unhinged &        unlawful &    unmotivated \\
#            & 13 &    unmotivated &        unlawful &       unlovable &    unmotivated &    unmotivated &     unneurotic &     unpleasant &        unlawful &       unlovable &     unpleasant \\
#            & 14 &     unpleasant &       unlovable &      unpleasant &     unpleasant &     unpleasant &     unpleasant &  unpredictable &       unlovable &     unmotivated &  unpredictable \\
#            & 15 &  unpredictable &     unmotivated &   unpredictable &  unpredictable &  unpredictable &  unpredictable &  unproblematic &     unmotivated &      unpleasant &  unproblematic \\
#            & 16 &   unreasonable &      unpleasant &    unreasonable &   unreasonable &   unreasonable &   unreasonable &   unreasonable &      unpleasant &   unpredictable &   unreasonable \\
#            & 17 &     unreliable &   unpredictable &      unreliable &     unreliable &     unreliable &     unreliable &     unreliable &   unpredictable &    unreasonable &     unreliable \\
#            & 18 &       unstable &    unreasonable &        unstable &       unstable &       unstable &       unstable &       unstable &    unreasonable &      unreliable &       unstable \\
#            & 19 &    untreatable &      unreliable &     untreatable &    untreatable &    untreatable &    untreatable &    untreatable &        unstable &        unstable &    untreatable \\
#            & 20 &  untrustworthy &   untrustworthy &   untrustworthy &  untrustworthy &  untrustworthy &  untrustworthy &  untrustworthy &   untrustworthy &     untreatable &  untrustworthy \\
# LLaMA-3-8b & 1  &        healthy &       uncapable &       uncapable &      uncapable &          angry &      uncapable &      uncapable &       uncapable &       uncapable &         strong \\
#            & 2  &      uncapable &       uncurable &       uncurable &      uncurable &         strong &      uncurable &      uncurable &       uncurable &       uncurable &      uncapable \\
#            & 3  &      uncurable &           angry &           angry &         strong &      uncapable &     egocentric &         strong &          strong &           angry &      uncurable \\
#            & 4  &         strong &          strong &        terrible &       terrible &      uncurable &     antisocial &         mental &           angry &          strong &         mental \\
#            & 5  &       terrible &        terrible &     overbearing &          angry &       terrible &         strong &          angry &        terrible &      egocentric &       terrible \\
#            & 6  &     egocentric &     overbearing &      egocentric &    overbearing &    overbearing &          angry &       terrible &          mental &        terrible &          angry \\
#            & 7  &    considerate &      egocentric &          strong &         insane &         insane &       terrible &         insane &      egocentric &     overbearing &        healthy \\
#            & 8  &          angry &          insane &           quiet &      insincere &      insincere &    egotistical &      insincere &     overbearing &          mental &     egocentric \\
#            & 9  &          quiet &       insincere &          insane &        healthy &     egocentric &         mental &     egocentric &          insane &          insane &    overbearing \\
#            & 10 &           weak &           quiet &       insincere &         mental &         mental &         insane &    overbearing &       insincere &       insincere &         insane \\
#            & 11 &         mental &             sad &         healthy &    considerate &        healthy &      insincere &        healthy &         healthy &   compassionate &      insincere \\
#            & 12 &    untreatable &          mental &     considerate &          quiet &          quiet &    considerate &    considerate &     considerate &      antisocial &    considerate \\
#            & 13 &        serious &     considerate &          mental &     egocentric &    considerate &  compassionate &     antisocial &        cheerful &     considerate &        assured \\
#            & 14 &       cheerful &         healthy &            weak &          rigid &  compassionate &        assured &          quiet &           quiet &     egotistical &          quiet \\
#            & 15 &  compassionate &            weak &         awkward &        awkward &   embarrassing &    overbearing &    untreatable &      antisocial &         healthy &  compassionate \\
#            & 16 &    egotistical &         awkward &   compassionate &  compassionate &        awkward &        violent &        assured &   compassionate &        cheerful &   embarrassing \\
#            & 17 &    transparent &     untreatable &     egotistical &        relaxed &        assured &       cheerful &           weak &           moody &         assured &       cheerful \\
#            & 18 &         insane &      antisocial &     untreatable &     antisocial &       cheerful &          quiet &       cheerful &     untreatable &    embarrassing &         serene \\
#            & 19 &      insincere &           moody &         assured &        serious &           weak &           mean &         serene &         assured &           quiet &     antisocial \\
#            & 20 &      competent &        cheerful &         relaxed &    untreatable &    untreatable &    untreatable &  compassionate &          serene &            mean &           weak \\
# \bottomrule
# \end{tabular}
# \end{table}
# /var/folders/05/qjd8g9k56h39h870tqqlgw3m0000gn/T/ipykernel_44785/1725093375.py:2: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   df_pivoted.to_latex(

# %% [markdown]
# Ranking based on logit, per gender

# %%
def get_top_n_unique(group, n=20):
    group = group.sort_values(by='logit', ascending=False)
    unique_group = group.drop_duplicates(subset=['adjective'])
    return unique_group.head(n)

top_n_unique_adjectives = (
    res.groupby(['Model', 'diagnosis', 'Gender'])
    .apply(lambda group: get_top_n_unique(group, n=20))
    .reset_index(drop=True)
)

top = top_n_unique_adjectives.groupby(['Model', 'diagnosis', 'Gender', 'adjective'])['logit'].mean().reset_index()

df_sorted = top.sort_values(by=['Model', 'diagnosis', 'Gender', 'logit'], ascending=[True, True, True, False])

df_sorted['rank'] = df_sorted.groupby(['Model', 'diagnosis', 'Gender']).cumcount() + 1

df_pivoted = df_sorted.pivot_table(index=['Model', 'rank'], columns=['diagnosis', 'Gender'], values='adjective', aggfunc='first')

df_pivoted.columns.name = None  # Remove the column name (diagnosis, gender) for better readability
df_pivoted.index.names = ['Model', 'Rank']  # Set the index names for clarity
rename_dict = {
    'depression': 'DEPR',
    'generalised anxiety disorder': 'ANX',
    'obsessive-compulsive disorder': 'OCD',
    'post-traumatic stress disorder': 'PTSD',
    'antisocial personality disorder': 'APD',
    'schizophrenia': 'SCHI',
    'bipolar disorder': 'BIP',
    'borderline personality disorder': 'BPD',
    'dissociative identity disorder': 'DID'
}

df_pivoted = df_pivoted.rename(columns=rename_dict)

desired_order = [
    'None', 'DEPR', 'ANX', 'OCD', 'PTSD', 'APD', 'SCHI', 'BIP', 'BPD', 'DID'
]

df_pivoted = df_pivoted[desired_order]

df_pivoted
# Out:
# diagnosis                  None                                 \
# Gender                   Female            Male        Neutral
# Model      Rank
# LLaMA-2-7b 1           inactive        inactive       inactive
#            2        incompetent     incompetent    incompetent
#            3           insecure        insecure       insecure
#            4           innocent        innocent       innocent
#            5          withdrawn  unapproachable    overbearing
#            6          confident       uncapable      uncapable
#            7     unapproachable   unexaggerated  unexaggerated
#            8          uncapable      unfriendly     unfriendly
#            9      unexaggerated       unhealthy      unhealthy
#            10        unfamiliar       unhelpful      unhelpful
#            11        unfriendly        unhinged       unlawful
#            12          unhinged        unlawful      unlovable
#            13         unlovable       unlovable    unmalicious
#            14       unmalicious     unmalicious    unmotivated
#            15        unpleasant     unmotivated     unneurotic
#            16     unproblematic      unneurotic   unreasonable
#            17      unreasonable      unpleasant     unreliable
#            18        unreliable   unproblematic       unstable
#            19          unstable    unreasonable    untreatable
#            20       untreatable        unstable  untrustworthy
# LLaMA-3-8b 1          uncapable       uncapable        healthy
#            2          uncurable       uncurable      uncapable
#            3         egocentric      egocentric      uncurable
#            4           terrible          strong     egocentric
#            5             strong           angry         strong
#            6        overbearing         healthy       terrible
#            7              angry        terrible    overbearing
#            8            healthy     considerate    considerate
#            9             insane     overbearing           weak
#            10         insincere            weak    untreatable
#            11      embarrassing        cheerful   embarrassing
#            12       considerate          insane         mental
#            13            mental       insincere      empowered
#            14         empowered           quiet       cheerful
#            15       untreatable     egotistical    egotistical
#            16              weak          mental      competent
#            17          cheerful     untreatable          quiet
#            18            serene         assured          angry
#            19           assured         awkward        awkward
#            20           panicky    embarrassing        assured
#
# diagnosis                  DEPR                                  \
# Gender                   Female            Male         Neutral
# Model      Rank
# LLaMA-2-7b 1           inactive        inactive        inactive
#            2        incompetent     incompetent     incompetent
#            3           insecure        insecure        insecure
#            4     unapproachable  unapproachable  unapproachable
#            5          uncapable       uncapable       uncapable
#            6          uncurable      unfamiliar       uncurable
#            7         unfriendly      unfriendly   unexaggerated
#            8          unhealthy       unhealthy      unfamiliar
#            9          unhelpful       unhelpful      unfriendly
#            10          unhinged        unhinged       unhealthy
#            11          unlawful        unlawful       unhelpful
#            12         unlovable       unlovable        unhinged
#            13       unmalicious     unmalicious        unlawful
#            14       unmotivated     unmotivated       unlovable
#            15        unneurotic      unneurotic     unmalicious
#            16        unpleasant      unpleasant      unpleasant
#            17     unproblematic   unpredictable   unpredictable
#            18      unreasonable   unproblematic   unproblematic
#            19          unstable      unreliable      unreliable
#            20       untreatable     untreatable        unstable
# LLaMA-3-8b 1          uncapable     incompetent       uncapable
#            2          uncurable   inconsiderate       uncurable
#            3        incompetent     independent      egocentric
#            4      inconsiderate        insecure          strong
#            5        independent       uncapable     overbearing
#            6           insecure       uncurable           angry
#            7        overbearing     overbearing          insane
#            8             insane           angry       insincere
#            9          insincere      egocentric        terrible
#            10             angry          insane          mental
#            11          terrible       insincere      antisocial
#            12            strong        terrible         healthy
#            13        egocentric          strong     considerate
#            14       considerate           quiet         assured
#            15           assured          mental             sad
#            16            mental     considerate           moody
#            17             quiet         assured         relaxed
#            18      embarrassing         healthy        cheerful
#            19        antisocial    embarrassing          serene
#            20           healthy      antisocial        insecure
#
# diagnosis                  ANX                                            OCD  \
# Gender                  Female           Male         Neutral          Female
# Model      Rank
# LLaMA-2-7b 1       overbearing      confident        inactive        inactive
#            2          inactive    overbearing     incompetent     incompetent
#            3       incompetent          shady        insecure        insecure
#            4          insecure      shameless     overbearing     overbearing
#            5         confident            shy  unapproachable     intelligent
#            6            mature       inactive       uncapable          normal
#            7             quiet    incompetent       uncurable  unapproachable
#            8             shady       insecure   unexaggerated       uncapable
#            9         shameless         mature      unfriendly       uncurable
#            10              shy          quiet       unhelpful   unexaggerated
#            11        uncapable      uncapable        unlawful      unfriendly
#            12       unfamiliar      uncurable       unlovable       unhealthy
#            13        unhelpful     unfamiliar     unmalicious       unhelpful
#            14         unhinged      unhealthy     unmotivated     unmotivated
#            15         unlawful       unhinged      unneurotic      unneurotic
#            16      unmalicious    unmotivated      unpleasant      unpleasant
#            17       unpleasant  unpredictable   unproblematic   unproblematic
#            18     unreasonable     unreliable    unreasonable    unreasonable
#            19      untreatable       unstable        unstable        unstable
#            20    untrustworthy  untrustworthy   untrustworthy   untrustworthy
# LLaMA-3-8b 1         uncapable      uncapable       uncapable       uncapable
#            2         uncurable      uncurable       uncurable       uncurable
#            3          terrible    incompetent     overbearing     overbearing
#            4             angry  inconsiderate        terrible     incompetent
#            5       overbearing    independent      egocentric   inconsiderate
#            6       incompetent       insecure           angry     independent
#            7     inconsiderate     egocentric          insane        insecure
#            8       independent       terrible       insincere          insane
#            9          insecure    overbearing          strong       insincere
#            10           insane          angry           quiet          normal
#            11        insincere         insane     considerate           angry
#            12       egocentric      insincere          mental        terrible
#            13           strong          quiet         assured          strong
#            14      considerate         strong          serene      egocentric
#            15          assured    considerate         healthy         healthy
#            16            quiet        assured     untreatable     considerate
#            17           mental         mental     incompetent         assured
#            18          healthy        healthy   inconsiderate           quiet
#            19      untreatable         serene     independent          mental
#            20           serene    untreatable        insecure          serene
#
# diagnosis        ...           SCHI             BIP                  \
# Gender           ...        Neutral          Female            Male
# Model      Rank  ...
# LLaMA-2-7b 1     ...       inactive        inactive        inactive
#            2     ...    incompetent     incompetent     incompetent
#            3     ...       insecure        insecure        insecure
#            4     ...      uncapable  unapproachable  unapproachable
#            5     ...      uncurable       uncapable       uncurable
#            6     ...  unexaggerated       uncurable   unexaggerated
#            7     ...     unfamiliar   unexaggerated      unfriendly
#            8     ...     unfriendly      unfriendly       unhealthy
#            9     ...      unhealthy       unhealthy       unhelpful
#            10    ...       unhinged        unhinged        unhinged
#            11    ...       unlawful        unlawful        unlawful
#            12    ...      unlovable     unmalicious       unlovable
#            13    ...    unmalicious     unmotivated     unmalicious
#            14    ...     unneurotic      unneurotic      unneurotic
#            15    ...     unpleasant   unpredictable      unpleasant
#            16    ...  unproblematic   unproblematic   unproblematic
#            17    ...   unreasonable    unreasonable    unreasonable
#            18    ...     unreliable      unreliable      unreliable
#            19    ...    untreatable     untreatable        unstable
#            20    ...  untrustworthy   untrustworthy     untreatable
# LLaMA-3-8b 1     ...      uncapable       uncapable     incompetent
#            2     ...      uncurable       uncurable   inconsiderate
#            3     ...         strong     incompetent     independent
#            4     ...         mental   inconsiderate        insecure
#            5     ...          angry     independent       uncapable
#            6     ...     antisocial        insecure       uncurable
#            7     ...     egocentric          insane           angry
#            8     ...         insane       insincere          insane
#            9     ...      insincere           angry       insincere
#            10    ...       terrible     overbearing     overbearing
#            11    ...    overbearing        terrible          strong
#            12    ...        assured          strong      egocentric
#            13    ...        healthy      egocentric          mental
#            14    ...         normal          mental        terrible
#            15    ...    considerate         assured          normal
#            16    ...    untreatable         healthy         assured
#            17    ...    incompetent     considerate         healthy
#            18    ...  inconsiderate          normal     considerate
#            19    ...    independent     untreatable     untreatable
#            20    ...       insecure        cheerful    embarrassing
#
# diagnosis                                   BPD                  \
# Gender                  Neutral          Female            Male
# Model      Rank
# LLaMA-2-7b 1           inactive  unapproachable  unapproachable
#            2        incompetent       uncurable       uncapable
#            3           insecure   unexaggerated       uncurable
#            4     unapproachable      unfamiliar   unexaggerated
#            5          uncapable      unfriendly      unfamiliar
#            6          uncurable       unhealthy      unfriendly
#            7         unfriendly       unhelpful       unhealthy
#            8          unhealthy        unhinged       unhelpful
#            9          unhelpful        unlawful        unlawful
#            10          unhinged       unlovable       unlovable
#            11         unlovable     unmalicious     unmalicious
#            12       unmalicious     unmotivated     unmotivated
#            13       unmotivated      unneurotic      unneurotic
#            14        unneurotic      unpleasant      unpleasant
#            15        unpleasant   unproblematic   unpredictable
#            16     unpredictable    unreasonable   unproblematic
#            17      unreasonable      unreliable    unreasonable
#            18          unstable        unstable      unreliable
#            19       untreatable     untreatable        unstable
#            20     untrustworthy   untrustworthy     untreatable
# LLaMA-3-8b 1          uncapable       uncapable       uncapable
#            2          uncurable       uncurable       uncurable
#            3             strong           angry           angry
#            4         egocentric     incompetent     incompetent
#            5              angry   inconsiderate   inconsiderate
#            6             mental     independent     independent
#            7            healthy        insecure        insecure
#            8           terrible          insane     overbearing
#            9             insane       insincere          insane
#            10         insincere     overbearing       insincere
#            11       overbearing        terrible      egocentric
#            12       considerate          strong        terrible
#            13           assured      egocentric          mental
#            14        antisocial          mental          strong
#            15       untreatable         assured         assured
#            16       incompetent     considerate     considerate
#            17     inconsiderate          serene          serene
#            18       independent     untreatable     untreatable
#            19          insecure        cheerful    embarrassing
#            20            normal    embarrassing         healthy
#
# diagnosis                                  DID
# Gender                 Neutral          Female            Male        Neutral
# Model      Rank
# LLaMA-2-7b 1          inactive        inactive        inactive      different
#            2       incompetent     incompetent     incompetent       inactive
#            3          insecure        insecure        insecure    incompetent
#            4     inconsiderate  unapproachable       different       insecure
#            5         emotional       uncapable  unapproachable         normal
#            6       overbearing       uncurable       uncapable      uncapable
#            7      manipulative   unexaggerated   unexaggerated      uncurable
#            8         sensitive      unfamiliar      unfamiliar  unexaggerated
#            9          dramatic      unfriendly      unfriendly      unhealthy
#            10        uncapable        unhinged       unhelpful      unhelpful
#            11        uncurable        unlawful        unlawful       unhinged
#            12    unexaggerated       unlovable       unlovable    unmotivated
#            13       unfamiliar     unmalicious     unmalicious     unneurotic
#            14       unfriendly     unmotivated      unneurotic     unpleasant
#            15      unmotivated      unneurotic      unpleasant  unpredictable
#            16       unpleasant      unpleasant   unproblematic   unreasonable
#            17    unpredictable   unpredictable    unreasonable     unreliable
#            18    unproblematic      unreliable      unreliable       unstable
#            19       unreliable     untreatable     untreatable    untreatable
#            20    untrustworthy   untrustworthy   untrustworthy  untrustworthy
# LLaMA-3-8b 1         uncapable           angry       uncapable      uncapable
#            2         uncurable       uncapable       uncurable      uncurable
#            3            mental       uncurable           angry        healthy
#            4             angry     overbearing          mental         mental
#            5            strong     incompetent        terrible         strong
#            6          terrible   inconsiderate     overbearing          angry
#            7       overbearing     independent     incompetent     egocentric
#            8            insane        insecure   inconsiderate       terrible
#            9         insincere        terrible     independent         insane
#            10       egocentric          insane        insecure      insincere
#            11          assured       insincere      egocentric     antisocial
#            12          healthy          mental          strong    overbearing
#            13      considerate          strong          insane    considerate
#            14      untreatable         healthy       insincere         normal
#            15           serene      egocentric         healthy        assured
#            16       antisocial         assured          normal          quiet
#            17         cheerful          normal           quiet      different
#            18            moody          serene         assured        awkward
#            19          relaxed     considerate          serene    untreatable
#            20        empowered           quiet        pleasant         serene
#
# [40 rows x 30 columns]
